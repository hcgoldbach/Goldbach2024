# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
plt.rcParams["font.family"] = "arial"
plt.rcParams["font.size"] = 6
plt.rcParams['axes.linewidth'] = 0.5
plt.rcParams['xtick.major.width'] = 0.25
plt.rcParams['xtick.major.size'] = 2
plt.rcParams['xtick.major.pad'] = 2

plt.rcParams['ytick.major.width'] = 0.25
plt.rcParams['ytick.major.size'] = 2
plt.rcParams['ytick.major.pad'] = 2
plt.rcParams['ytick.major.pad'] = 2

plt.rcParams['axes.labelpad'] = 2

# %%
thalamus = pd.read_excel('../data/Fig4/Fig4_in.xlsx', sheet_name = 'thalamus')

perDMS = thalamus[(thalamus['inj'] == 'DMS')&(thalamus['region'] == 'thalamus')]
perDLS = thalamus[(thalamus['inj'] == 'DLS')&(thalamus['region'] == 'thalamus')]

# %%
perDMS = perDMS.sort_values('area')
perDLS = perDLS.sort_values('area')

# %%
fig, ax = plt.subplots(2,1, figsize = (2.5,2.2), sharey = True)
sns.barplot(ax = ax[0], data = perDMS, x = 'area', y = 'perCells', color = 'cornflowerblue', errorbar = ('se'), err_kws={'linewidth': 1}, alpha = 0.7)
sns.barplot(ax = ax[1], data = perDLS, x = 'area', y = 'perCells', color = 'goldenrod', errorbar = ('se'), err_kws={'linewidth': 1}, alpha = 0.7)

ax[0].tick_params(axis='x', labelrotation=90)
ax[1].tick_params(axis='x', labelrotation=90)
ax[0].set_xlabel(None)
ax[0].set_ylabel('Cells (%)')
ax[1].set_ylabel('Cells (%)')
ax[1].set_xlabel('Thalamic nucleus')

sns.despine(offset = 1)
plt.tight_layout()
plt.savefig('../figOutputs/Supp4-1_thalamusCounts.pdf', dpi = 300, transparent = True, bbox_inches = 'tight')

# %%
bgDMS = thalamus[(thalamus['inj'] == 'DMS')&(thalamus['region'] == 'basalGanglia')]
bgDLS = thalamus[(thalamus['inj'] == 'DLS')&(thalamus['region'] == 'basalGanglia')]

# %%
fig, ax = plt.subplots(2,1, figsize = (2.5,2.2), sharey = True)
sns.barplot(ax = ax[0], data = bgDMS, x = 'area', y = 'perCells', color = 'cornflowerblue', errorbar = ('se'), err_kws={'linewidth': 1}, alpha = 0.7)
sns.barplot(ax = ax[1], data = bgDLS, x = 'area', y = 'perCells', color = 'goldenrod', errorbar = ('se'), err_kws={'linewidth': 1}, alpha = 0.7)

ax[0].tick_params(axis='x', labelrotation=90)
ax[1].tick_params(axis='x', labelrotation=90)
ax[0].set_xlabel(None)
ax[0].set_ylabel('Cells (%)')
ax[1].set_ylabel('Cells (%)')
ax[1].set_xlabel('Basal Ganglia area')
ax[0].set_yscale('log')
ax[0].set_yticks([1, 10, 100])
ax[0].set_yticklabels([1, 10, 100])

sns.despine(offset = 1)
plt.tight_layout()
plt.savefig('../figOutputs/Supp4-1_bgCounts.pdf', dpi = 300, transparent = True, bbox_inches = 'tight')

# %%
mbDMS = thalamus[(thalamus['inj'] == 'DMS')&(thalamus['region'] == 'midbrain')]
mbDLS = thalamus[(thalamus['inj'] == 'DLS')&(thalamus['region'] == 'midbrain')]

# %%
fig, ax = plt.subplots(2,1, figsize = (2.5,2.2), sharey = True)
sns.barplot(ax = ax[0], data = mbDMS, x = 'area', y = 'perCells', color = 'cornflowerblue', errorbar = ('se'), err_kws={'linewidth': 1}, alpha = 0.7)
sns.barplot(ax = ax[1], data = mbDLS, x = 'area', y = 'perCells', color = 'goldenrod', errorbar = ('se'), err_kws={'linewidth': 1}, alpha = 0.7)

ax[0].tick_params(axis='x', labelrotation=90)
ax[1].tick_params(axis='x', labelrotation=90)
ax[0].set_xlabel(None)
ax[0].set_ylabel('Cells (%)')
ax[1].set_ylabel('Cells (%)')
ax[1].set_xlabel('Midbrain area')

sns.despine(offset = 1)
plt.tight_layout()
plt.savefig('../figOutputs/Supp4-1_mbCounts.pdf', dpi = 300, transparent = True, bbox_inches = 'tight')

# %%
regions = pd.read_excel('../data/Fig4/Fig4_in.xlsx', sheet_name = 'region')

# %%
fig, ax = plt.subplots(2,1, figsize = (2.5,2.2), sharey = True)
sns.barplot(ax = ax[0], data = regions[regions['inj'] == 'DMS'], x = 'region', y = 'perCells', color = 'cornflowerblue', errorbar = ('se'), err_kws={'linewidth': 1.5}, alpha = 0.7)
sns.barplot(ax = ax[1], data = regions[regions['inj'] == 'DLS'], x = 'region', y = 'perCells', color = 'goldenrod', errorbar = ('se'), err_kws={'linewidth': 1.5}, alpha = 0.7)

ax[0].tick_params(axis='x', labelrotation=90)
ax[1].tick_params(axis='x', labelrotation=90)
ax[0].set_xlabel(None)
ax[0].set_ylabel('Cells (%)')
ax[1].set_ylabel('Cells (%)')
ax[1].set_xlabel('Region')
ax[0].set_xticks([0,1,2,3])
ax[0].set_xticklabels(['CTX', 'BG', 'MB', 'TH'])

ax[1].set_xticks([0,1,2,3])
ax[1].set_xticklabels(['CTX', 'BG', 'MB', 'TH'])

sns.despine(offset = 1)
plt.tight_layout()
plt.savefig('../figOutputs/Supp4-1_regionalCounts.pdf', dpi = 300, transparent = True, bbox_inches = 'tight')
